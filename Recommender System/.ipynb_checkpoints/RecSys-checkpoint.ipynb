# %% [markdown]
# # Recommender System
# ## Group 7
#
# This shows some attempts to build a recommender system

# %%
# import libraries
import graphlab as gl
import numpy as np
import pandas as pd

# %% [markdown]
# ## Input data : keep a dataframe containing user-item interactions

# %%
# create SFrame for Amsterdam ins data
amsterdam_sf = gl.SFrame.read_csv('..//DataSources//FourCityDataset//instagram//amsterdam.txt',
                        delimiter=' ',header=False)
amsterdam_sf.rename({'X1':'user_id','X2':'venue_id','X3':'#visits(normalized)'})
# Out:
# Finished parsing file E:\DST-3rd\IN4325 Information Retrieval\RecommenderSys\IR_RecommendationHE\DataSources\FourCityDataset\instagram\amsterdam.txt
# Parsing completed. Parsed 100 lines in 0.069014 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[long,str,float]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Finished parsing file E:\DST-3rd\IN4325 Information Retrieval\RecommenderSys\IR_RecommendationHE\DataSources\FourCityDataset\instagram\amsterdam.txt
# Parsing completed. Parsed 25442 lines in 0.071897 secs.
# Columns:
# 	user_id	int
# 	venue_id	str
# 	#visits(normalized)	float
#
# Rows: 25442
#
# Data:
# +-----------+--------------------------+---------------------+
# |  user_id  |         venue_id         | #visits(normalized) |
# +-----------+--------------------------+---------------------+
# |  7546845  | 4d9e0491baae54817c8aff64 |    0.666666666667   |
# | 574349047 | 4aa8b27bf964a520b65120e3 |    0.833333333333   |
# | 263031464 | 4f91796ee4b0d5d7897f3a13 |    0.666666666667   |
# | 272238078 | 4c6bd9fb9669e21e7acdab51 |    0.666666666667   |
# | 476498302 | 4bd6befa6798ef3bba83658d |    0.666666666667   |
# | 616834777 | 4a27083ff964a52013901fe3 |    0.666666666667   |
# | 209919551 | 4aa68d04f964a520274a20e3 |         0.75        |
# | 323561614 | 4a270748f964a5207b8d1fe3 |    0.666666666667   |
# | 250275530 | 514e0cbce4b0679548f4d62a |    0.833333333333   |
# |  29782417 | 4a27009ff964a520e4831fe3 |         0.75        |
# +-----------+--------------------------+---------------------+
# [25442 rows x 3 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
amsterdam_sf.head(5)
# Out:
# Columns:
# 	user_id	int
# 	venue_id	str
# 	#visits(normalized)	float
#
# Rows: 5
#
# Data:
# +-----------+--------------------------+---------------------+
# |  user_id  |         venue_id         | #visits(normalized) |
# +-----------+--------------------------+---------------------+
# |  7546845  | 4d9e0491baae54817c8aff64 |    0.666666666667   |
# | 574349047 | 4aa8b27bf964a520b65120e3 |    0.833333333333   |
# | 263031464 | 4f91796ee4b0d5d7897f3a13 |    0.666666666667   |
# | 272238078 | 4c6bd9fb9669e21e7acdab51 |    0.666666666667   |
# | 476498302 | 4bd6befa6798ef3bba83658d |    0.666666666667   |
# +-----------+--------------------------+---------------------+
# [5 rows x 3 columns]

# %% [markdown]
# ## Keep another list for iem metadata
# todo: enrich the metadata from foursquare

# %%
#items = gl.SFrame.read_csv(...)

# %% [markdown]
# ## Create a simple model
# 1. Random split data into training data and validation data
# 2. We have a target column: #visits, thus we can create a model to predict which new places a user would visit frequently.

# %%
# split data into training and validation
training_data, validation_data = gl.recommender.util.random_split_by_user(amsterdam_sf, 'user_id', 'venue_id')
ranking_factorization_model = gl.recommender.create(training_data, 'user_id', 'venue_id',target='#visits(normalized)')
# Out:
# Recsys training: model = ranking_factorization_recommender
# Preparing data set.
#     Data has 24266 observations with 4317 users and 5617 items.
#     Data prepared in: 0.052289s
# Training ranking_factorization_recommender for recommendations.
# +--------------------------------+--------------------------------------------------+----------+
# | Parameter                      | Description                                      | Value    |
# +--------------------------------+--------------------------------------------------+----------+
# | num_factors                    | Factor Dimension                                 | 32       |
# | regularization                 | L2 Regularization on Factors                     | 1e-009   |
# | solver                         | Solver used for training                         | sgd      |
# | linear_regularization          | L2 Regularization on Linear Coefficients         | 1e-009   |
# | ranking_regularization         | Rank-based Regularization Weight                 | 0.25     |
# | max_iterations                 | Maximum Number of Iterations                     | 25       |
# +--------------------------------+--------------------------------------------------+----------+
#   Optimizing model using SGD; tuning step size.
#   Using 10000 / 24266 points for tuning the step size.
# +---------+-------------------+------------------------------------------+
# | Attempt | Initial Step Size | Estimated Objective Value                |
# +---------+-------------------+------------------------------------------+
# | 0       | 25                | Not Viable                               |
# | 1       | 6.25              | Not Viable                               |
# | 2       | 1.5625            | Not Viable                               |
# | 3       | 0.390625          | 0.00426741                               |
# | 4       | 0.195312          | 0.00413146                               |
# | 5       | 0.0976562         | 0.00428614                               |
# | 6       | 0.0488281         | 0.00461616                               |
# | 7       | 0.0244141         | 0.0050549                                |
# +---------+-------------------+------------------------------------------+
# | Final   | 0.195312          | 0.00413146                               |
# +---------+-------------------+------------------------------------------+
# Starting Optimization.
# +---------+--------------+-------------------+-----------------------+-------------+
# | Iter.   | Elapsed Time | Approx. Objective | Approx. Training RMSE | Step Size   |
# +---------+--------------+-------------------+-----------------------+-------------+
# | Initial | 501us        | 0.00634811        | 0.0568311             |             |
# +---------+--------------+-------------------+-----------------------+-------------+
# | 1       | 69.51ms      | 0.00748275        | 0.066591              | 0.195312    |
# | 2       | 190.091ms    | 0.00640354        | 0.0625909             | 0.116134    |
# | 3       | 237.625ms    | 0.00585096        | 0.059261              | 0.0856819   |
# | 4       | 298.668ms    | 0.00552771        | 0.0576124             | 0.0580668   |
# | 5       | 340.199ms    | 0.00536474        | 0.0566208             | 0.0491185   |
# | 6       | 381.727ms    | 0.00529542        | 0.0562981             | 0.042841    |
# | 11      | 592.376ms    | 0.00509           | 0.0550608             | 0.0271912   |
# | 25      | 952.633ms    | 0.00484849        | 0.053304              | 0.00617632  |
# +---------+--------------+-------------------+-----------------------+-------------+
# Optimization Complete: Maximum number of passes through the data reached.
# Computing final objective value and training RMSE.
#        Final objective value: 0.00476655
#        Final training RMSE: 0.052695

# %% [markdown]
# ## Use the model created to recommend places to a user

# %%
# first select a user, and see where he/she has visited
mask = amsterdam_sf['user_id']==7546845
amsterdam_sf[mask]
# Out:
# Columns:
# 	user_id	int
# 	venue_id	str
# 	#visits(normalized)	float
#
# Rows: Unknown
#
# Data:
# +---------+--------------------------+---------------------+
# | user_id |         venue_id         | #visits(normalized) |
# +---------+--------------------------+---------------------+
# | 7546845 | 4d9e0491baae54817c8aff64 |    0.666666666667   |
# | 7546845 | 4a995531f964a520da2d20e3 |    0.666666666667   |
# | 7546845 | 4de6588a18389f0558772bbf |    0.666666666667   |
# | 7546845 | 4c06841f191f20a128a2e414 |    0.666666666667   |
# | 7546845 | 4a27079bf964a5205a8e1fe3 |    0.666666666667   |
# | 7546845 | 4a2705e6f964a5204a891fe3 |         0.75        |
# | 7546845 | 4f707285e4b03b575ed77f23 |    0.666666666667   |
# +---------+--------------------------+---------------------+
# [? rows x 3 columns]
# Note: Only the head of the SFrame is printed. This SFrame is lazily evaluated.
# You can use sf.materialize() to force materialization.

# %%
# recommend top3 places for this user
model.recommend(users=['7546845'],k=3)
# Out:
# Columns:
# 	user_id	int
# 	venue_id	str
# 	score	float
# 	rank	int
#
# Rows: 3
#
# Data:
# +---------+--------------------------+-----------------+------+
# | user_id |         venue_id         |      score      | rank |
# +---------+--------------------------+-----------------+------+
# | 7546845 | 4bcc79fdcc8cd13a6ff1c0cf | 0.0550000071526 |  1   |
# | 7546845 | 4a27075ef964a520b78d1fe3 | 0.0498575568199 |  2   |
# | 7546845 | 4e6de5bda8093d29ff034458 | 0.0476190447807 |  3   |
# +---------+--------------------------+-----------------+------+
# [3 rows x 4 columns]

# %%
graphlab.canvas.set_target('ipynb')
view = model.views.overview(validation_set=validation_data)
view.show()

# %% [markdown]
# ## create a popularity model as our baseline
# This model just recommend based on popularity, no personalization

# %%
popularity_model = graphlab.popularity_recommender.create(training_data,
                                                         user_id='user_id',
                                                         item_id='venue_id')
# Out:
# Recsys training: model = popularity
# Warning: Column '#visits(normalized)' ignored.
#     To use this column as the target, set target = "#visits(normalized)" and use a method that allows the use of a target.
# Preparing data set.
#     Data has 24266 observations with 4317 users and 5617 items.
#     Data prepared in: 0.062503s
# 24266 observations to process; with 5617 unique items.

# %%
model_performance = graphlab.compare(validation_data, [popularity_model, model], user_sample=0.8)
graphlab.show_comparison(model_performance,[popularity_model,model])
# Out:
# compare_models: using 524 users to estimate model performance
# PROGRESS: Evaluate model M0
#
# Precision and recall summary statistics by cutoff
# +--------+-----------------+------------------+
# | cutoff |  mean_precision |   mean_recall    |
# +--------+-----------------+------------------+
# |   1    |  0.013358778626 | 0.00578880407125 |
# |   2    | 0.0219465648855 | 0.0239821882952  |
# |   3    | 0.0209923664122 | 0.0360687022901  |
# |   4    | 0.0190839694656 | 0.0432888040712  |
# |   5    |  0.019465648855 |  0.055534351145  |
# |   6    | 0.0174936386768 | 0.0601781170483  |
# |   7    | 0.0155398037077 | 0.0630407124682  |
# |   8    | 0.0140744274809 | 0.0668575063613  |
# |   9    | 0.0139949109415 | 0.0727417302799  |
# |   10   |  0.013358778626 | 0.0781488549618  |
# +--------+-----------------+------------------+
# [10 rows x 3 columns]
#
# PROGRESS: Evaluate model M1
#
# Precision and recall summary statistics by cutoff
# +--------+------------------+------------------+
# | cutoff |  mean_precision  |   mean_recall    |
# +--------+------------------+------------------+
# |   1    |       0.0        |       0.0        |
# |   2    | 0.00572519083969 | 0.00461195928753 |
# |   3    | 0.00763358778626 | 0.0110368956743  |
# |   4    | 0.00572519083969 | 0.0110368956743  |
# |   5    | 0.00458015267176 | 0.0110368956743  |
# |   6    | 0.00477099236641 | 0.0142175572519  |
# |   7    | 0.00627044711014 | 0.0247773536896  |
# |   8    | 0.00667938931298 | 0.0309796437659  |
# |   9    | 0.00614927905004 | 0.0316157760814  |
# |   10   | 0.00667938931298 | 0.0367684478372  |
# +--------+------------------+------------------+
# [10 rows x 3 columns]
#
# Model compare metric: precision_recall

# %% [markdown]
# ## As shown above, our model now performs badly....
# ### We should enrich our data and train a much better model!!
